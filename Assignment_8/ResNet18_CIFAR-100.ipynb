# %%
# !python train.py --lr 0.1 --batch-size 128 --epochs 100
# Out:
# 100% 169M/169M [00:14<00:00, 12.0MB/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# ==> Building model..
#
# Epoch: 0
# Training: 100% 391/391 [00:47<00:00,  8.30it/s, Loss=3.822, Acc=11.412%]
# Testing: 100% 100/100 [00:03<00:00, 28.82it/s, Loss=3.357, Acc=19.270%]
# Saving..
#
# Epoch: 1
# Training: 100% 391/391 [00:42<00:00,  9.24it/s, Loss=3.106, Acc=23.204%]
# Testing: 100% 100/100 [00:03<00:00, 32.43it/s, Loss=3.044, Acc=25.900%]
# Saving..
#
# Epoch: 2
# Training: 100% 391/391 [00:42<00:00,  9.23it/s, Loss=2.686, Acc=31.056%]
# ...
